# %% [markdown]
# <a href="https://colab.research.google.com/github/sonuku092/Stock_Prediction/blob/main/Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data =pd.read_csv('GOOG.csv')

# %%
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data
# Out:
#      symbol                       date    close      high        low     open  \
# 0      GOOG  2016-06-14 00:00:00+00:00   718.27   722.470   713.1200   716.48
# 1      GOOG  2016-06-15 00:00:00+00:00   718.92   722.980   717.3100   719.00
# 2      GOOG  2016-06-16 00:00:00+00:00   710.36   716.650   703.2600   714.91
# 3      GOOG  2016-06-17 00:00:00+00:00   691.72   708.820   688.4515   708.65
# 4      GOOG  2016-06-20 00:00:00+00:00   693.71   702.480   693.4100   698.77
# ...     ...                        ...      ...       ...        ...      ...
# 1253   GOOG  2021-06-07 00:00:00+00:00  2466.09  2468.000  2441.0725  2451.32
# 1254   GOOG  2021-06-08 00:00:00+00:00  2482.85  2494.495  2468.2400  2479.90
# 1255   GOOG  2021-06-09 00:00:00+00:00  2491.40  2505.000  2487.3300  2499.50
# 1256   GOOG  2021-06-10 00:00:00+00:00  2521.60  2523.260  2494.0000  2494.01
# 1257   GOOG  2021-06-11 00:00:00+00:00  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  divCash  \
# 0     1306065    718.27   722.470   713.1200   716.48    1306065      0.0
# 1     1214517    718.92   722.980   717.3100   719.00    1214517      0.0
# 2     1982471    710.36   716.650   703.2600   714.91    1982471      0.0
# 3     3402357    691.72   708.820   688.4515   708.65    3402357      0.0
# 4     2082538    693.71   702.480   693.4100   698.77    2082538      0.0
# ...       ...       ...       ...        ...      ...        ...      ...
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453      0.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253      0.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337      0.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733      0.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309      0.0
#
#       splitFactor
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
# 1257          1.0
#
# [1258 rows x 14 columns]

# %%
google_stock_data.tail()
# Out:
#      symbol                       date    close      high        low     open  \
# 1253   GOOG  2021-06-07 00:00:00+00:00  2466.09  2468.000  2441.0725  2451.32
# 1254   GOOG  2021-06-08 00:00:00+00:00  2482.85  2494.495  2468.2400  2479.90
# 1255   GOOG  2021-06-09 00:00:00+00:00  2491.40  2505.000  2487.3300  2499.50
# 1256   GOOG  2021-06-10 00:00:00+00:00  2521.60  2523.260  2494.0000  2494.01
# 1257   GOOG  2021-06-11 00:00:00+00:00  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  divCash  \
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453      0.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253      0.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337      0.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733      0.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309      0.0
#
#       splitFactor
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
# 1257          1.0

# %%
google_stock_data = google_stock_data[['date','open','close']]
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0]))
google_stock_data.set_index('date',drop=True,inplace=True)
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %%
#Data Preprocessing
from sklearn.preprocessing import MinMaxScaler
MMS=MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data)*0.80)
training_size
# Out:
# 1006

# %%
train_data =google_stock_data[:training_size]
test_data = google_stock_data[training_size:]

# %%
train_data.shape,test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout ,LSTM ,Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 8s 85ms/step - loss: 0.0070 - mean_absolute_error: 0.0571 - val_loss: 0.0173 - val_mean_absolute_error: 0.1139
# Epoch 2/80
# 30/30 [==============================] - 2s 57ms/step - loss: 7.7317e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0032 - val_mean_absolute_error: 0.0449
# Epoch 3/80
# 30/30 [==============================] - 2s 63ms/step - loss: 5.1553e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0024 - val_mean_absolute_error: 0.0386
# Epoch 4/80
# 30/30 [==============================] - 2s 61ms/step - loss: 4.7773e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 5/80
# 30/30 [==============================] - 2s 61ms/step - loss: 4.5749e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0040 - val_mean_absolute_error: 0.0515
# Epoch 6/80
# 30/30 [==============================] - 3s 91ms/step - loss: 4.5729e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0026 - val_mean_absolute_error: 0.0404
# Epoch 7/80
# 30/30 [==============================] - 2s 61ms/step - loss: 4.2551e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0022 - val_mean_absolute_error: 0.0362
# Epoch 8/80
# 30/30 [==============================] - 2s 53ms/step - loss: 4.2932e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0047 - val_mean_absolute_error: 0.0548
# Epoch 9/80
# 30/30 [==============================] - 2s 53ms/step - loss: 3.9427e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0046 - val_mean_absolute_error: 0.0550
# Epoch 10/80
# 30/30 [==============================] - 2s 54ms/step - loss: 3.7930e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0053 - val_mean_absolute_error: 0.0569
# Epoch 11/80
# 30/30 [==============================] - 2s 58ms/step - loss: 3.5598e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0052 - val_mean_absolute_error: 0.0559
# Epoch 12/80
# 30/30 [==============================] - 2s 65ms/step - loss: 3.4852e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0056 - val_mean_absolute_error: 0.0592
# Epoch 13/80
# 30/30 [==============================] - 3s 92ms/step - loss: 3.3429e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0087 - val_mean_absolute_error: 0.0768
# Epoch 14/80
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2873e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0064 - val_mean_absolute_error: 0.0630
# Epoch 15/80
# 30/30 [==============================] - 2s 57ms/step - loss: 3.0789e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0066 - val_mean_absolute_error: 0.0657
# Epoch 16/80
# 30/30 [==============================] - 3s 90ms/step - loss: 2.9896e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0095 - val_mean_absolute_error: 0.0803
# Epoch 17/80
# 30/30 [==============================] - 2s 61ms/step - loss: 3.2586e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0049 - val_mean_absolute_error: 0.0541
# Epoch 18/80
# 30/30 [==============================] - 2s 61ms/step - loss: 3.0535e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0084 - val_mean_absolute_error: 0.0760
# Epoch 19/80
# 30/30 [==============================] - 3s 101ms/step - loss: 2.9045e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0047 - val_mean_absolute_error: 0.0517
# Epoch 20/80
# 30/30 [==============================] - 2s 75ms/step - loss: 2.8606e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0068 - val_mean_absolute_error: 0.0648
# Epoch 21/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.9323e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0065 - val_mean_absolute_error: 0.0645
# Epoch 22/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.6759e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0064 - val_mean_absolute_error: 0.0642
# Epoch 23/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.7290e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0042 - val_mean_absolute_error: 0.0489
# Epoch 24/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.8118e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0057 - val_mean_absolute_error: 0.0597
# Epoch 25/80
# 30/30 [==============================] - 2s 76ms/step - loss: 2.6213e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0064 - val_mean_absolute_error: 0.0643
# Epoch 26/80
# 30/30 [==============================] - 2s 79ms/step - loss: 2.8739e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0078 - val_mean_absolute_error: 0.0718
# Epoch 27/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.5310e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0073 - val_mean_absolute_error: 0.0688
# Epoch 28/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.5193e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0051 - val_mean_absolute_error: 0.0558
# Epoch 29/80
# 30/30 [==============================] - 2s 77ms/step - loss: 2.8304e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0058 - val_mean_absolute_error: 0.0607
# Epoch 30/80
# 30/30 [==============================] - 3s 90ms/step - loss: 2.5676e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0062 - val_mean_absolute_error: 0.0641
# Epoch 31/80
# 30/30 [==============================] - 2s 72ms/step - loss: 2.5838e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 32/80
# 30/30 [==============================] - 3s 86ms/step - loss: 2.3575e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0065 - val_mean_absolute_error: 0.0660
# Epoch 33/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.4241e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0050 - val_mean_absolute_error: 0.0575
# Epoch 34/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.3137e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0037 - val_mean_absolute_error: 0.0483
# Epoch 35/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.5805e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0060 - val_mean_absolute_error: 0.0648
# Epoch 36/80
# 30/30 [==============================] - 2s 60ms/step - loss: 2.3428e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0024 - val_mean_absolute_error: 0.0373
# Epoch 37/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.1896e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0037 - val_mean_absolute_error: 0.0474
# Epoch 38/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.4548e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0040 - val_mean_absolute_error: 0.0504
# Epoch 39/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.2270e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0030 - val_mean_absolute_error: 0.0442
# Epoch 40/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.1842e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 41/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.0629e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0038 - val_mean_absolute_error: 0.0492
# Epoch 42/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.5121e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0024 - val_mean_absolute_error: 0.0366
# Epoch 43/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.6099e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 44/80
# 30/30 [==============================] - 2s 66ms/step - loss: 2.4211e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0022 - val_mean_absolute_error: 0.0345
# Epoch 45/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.1765e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 46/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.0425e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0032 - val_mean_absolute_error: 0.0422
# Epoch 47/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.0399e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0051 - val_mean_absolute_error: 0.0585
# Epoch 48/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.9995e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0042 - val_mean_absolute_error: 0.0497
# Epoch 49/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.9774e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0030 - val_mean_absolute_error: 0.0410
# Epoch 50/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.5090e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0035 - val_mean_absolute_error: 0.0446
# Epoch 51/80
# 30/30 [==============================] - 2s 67ms/step - loss: 1.8776e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0020 - val_mean_absolute_error: 0.0314
# Epoch 52/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.8555e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0036 - val_mean_absolute_error: 0.0439
# Epoch 53/80
# 30/30 [==============================] - 2s 64ms/step - loss: 1.8168e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0042 - val_mean_absolute_error: 0.0482
# Epoch 54/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.9799e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0038 - val_mean_absolute_error: 0.0441
# Epoch 55/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.7903e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0044 - val_mean_absolute_error: 0.0524
# Epoch 56/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7430e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0033 - val_mean_absolute_error: 0.0397
# Epoch 57/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.7619e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 58/80
# 30/30 [==============================] - 2s 79ms/step - loss: 1.6850e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0017 - val_mean_absolute_error: 0.0282
# Epoch 59/80
# 30/30 [==============================] - 2s 72ms/step - loss: 1.8447e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0040 - val_mean_absolute_error: 0.0447
# Epoch 60/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.6451e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0042 - val_mean_absolute_error: 0.0509
# Epoch 61/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.8457e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0052 - val_mean_absolute_error: 0.0575
# Epoch 62/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.9306e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0018 - val_mean_absolute_error: 0.0301
# Epoch 63/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.6720e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0374
# Epoch 64/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.5984e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0032 - val_mean_absolute_error: 0.0385
# Epoch 65/80
# 30/30 [==============================] - 3s 99ms/step - loss: 1.5740e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0347
# Epoch 66/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.7087e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0050 - val_mean_absolute_error: 0.0553
# Epoch 67/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.5460e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0036 - val_mean_absolute_error: 0.0444
# Epoch 68/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.7249e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0059 - val_mean_absolute_error: 0.0627
# Epoch 69/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.5329e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0045 - val_mean_absolute_error: 0.0520
# Epoch 70/80
# 30/30 [==============================] - 2s 64ms/step - loss: 1.5635e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0045 - val_mean_absolute_error: 0.0501
# Epoch 71/80
# 30/30 [==============================] - 2s 78ms/step - loss: 1.4630e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0044 - val_mean_absolute_error: 0.0474
# Epoch 72/80
# 30/30 [==============================] - 2s 80ms/step - loss: 1.5014e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0064 - val_mean_absolute_error: 0.0634
# Epoch 73/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.5504e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0042 - val_mean_absolute_error: 0.0463
# Epoch 74/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.4896e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0046 - val_mean_absolute_error: 0.0479
# Epoch 75/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.6010e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0050 - val_mean_absolute_error: 0.0527
# Epoch 76/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.5629e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0034 - val_mean_absolute_error: 0.0381
# Epoch 77/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.5577e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0035 - val_mean_absolute_error: 0.0426
# Epoch 78/80
# 30/30 [==============================] - 3s 86ms/step - loss: 1.4646e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 79/80
# 30/30 [==============================] - 2s 70ms/step - loss: 1.5239e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0039 - val_mean_absolute_error: 0.0449
# Epoch 80/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.4362e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0046 - val_mean_absolute_error: 0.0500

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 3s 15ms/step
# array([[0.47854346, 0.474581  ],
#        [0.48546132, 0.4813664 ],
#        [0.489952  , 0.4858704 ],
#        [0.503613  , 0.49823758],
#        [0.5146743 , 0.5086351 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1558.1813, 1547.82  ],
#        [1571.0065, 1560.3956],
#        [1579.3318, 1568.743 ],
#        [1604.6582, 1591.6636],
#        [1625.165 , 1610.9338]], dtype=float32)

# %%
gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']])

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1558.181274      1547.819946
# 2020-08-25  1582.07  1608.22     1571.006470      1560.395630
# 2020-08-26  1608.00  1652.38     1579.331787      1568.743042
# 2020-08-27  1653.68  1634.33     1604.658203      1591.663574
# 2020-08-28  1633.49  1644.41     1625.165039      1610.933838

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2422.145996      2171.468994
# 2021-06-10  2494.01  2521.60     2437.314453      2183.407959
# 2021-06-11  2524.92  2513.93     2446.093750      2190.300537
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
